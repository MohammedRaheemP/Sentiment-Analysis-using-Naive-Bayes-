# %% [markdown]
# **Twitter Sentiment Analysis using Naive Bayes Algorithm**

# %%
#importing nltk to download twitter_samples,stopwords
import nltk

# %%
#we have to download those to our pc
nltk.download('twitter_samples')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package twitter_samples to /root/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#importing from nltk-corpus
from nltk.corpus import twitter_samples,stopwords

# %%
pos_tweets=twitter_samples.strings('positive_tweets.json')
neg_tweets=twitter_samples.strings('negative_tweets.json')

# %%
#type
type(pos_tweets)
# Out:
# list

# %%
#an eg, first tweet
pos_tweets[0]
# Out:
# '#FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)'

# %%
#length of pos tweets
len(pos_tweets)
# Out:
# 5000

# %%
#len of neg tweets
len(neg_tweets)
# Out:
# 5000

# %%
#an eg of neg tweet,
neg_tweets[22]
# Out:
# 'just want to play video games/watch movies with someone :('

# %% [markdown]
# here we have 5000 positive tweets and 5000 negative tweets.
# both are located in like strings in a list.

# %% [markdown]
# # 1. Train Test split,

# %%
#train - 80% of tweets from both
train_pos = pos_tweets[:4000]
train_neg = neg_tweets[:4000]
train = train_pos + train_neg
test_pos = pos_tweets[4000:]
test_neg = neg_tweets[4000:] 
test = test_pos + test_neg

#length confirmation
print(f'length of train data : {len(train)}')
print(f'length of test data : {len(test)}')
# Out:
# length of train data : 8000
# length of test data : 2000

# %% [markdown]
# Now we have 8000 train data(includes 4000 pos and 4000 neg)
# and 2000 test data(includes 1000 pos and 1000 neg)

# %% [markdown]
# # 2. Making Label for both train and test set

# %%
import numpy as np
train_label=np.append((np.ones(4000)),np.zeros(4000))
test_label=np.append((np.ones(1000)),np.zeros(1000))
#shapes
print(train_label.shape)
print(test_label.shape)
# Out:
# (8000,)
# (2000,)

# %% [markdown]
# # 3. Processing Data

# %%
#let's see one tweet, how is looking
train[0]
# Out:
# '#FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)'

# %% [markdown]
# here we can see a string which includes words,hashtag,symbols, etc meaningless terms. remove those to get it easy

# %% [markdown]
# * feature extraction is very important before feeding into any ML models.

# %%
import re
import string

from nltk.tokenize import TweetTokenizer
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

# %%
#making a function to process
def process(tweet):
  #input : a tweet
  #output : a list of cleaned words
  
  tweet=re.sub(r'#','',tweet)  #hashtag removals
  tweet=re.sub(r'\$\w*','',tweet)  #stockticket removals
  tweet=re.sub(r'https?:\/\/.*[\r\n]*','',tweet)  #hyperlinks removals
  tweet=re.sub(r'^RT[\s]+','',tweet)   #retweets removals

  tokenizer=TweetTokenizer(preserve_case=False, reduce_len=True, strip_handles=True)
  tokens=tokenizer.tokenize(tweet)

  eng_stopwords=stopwords.words('english')
  punctuations=string.punctuation
  stemmer=PorterStemmer()

  cleaned_tokens=[]
  for word in tokens:
    if (word not in eng_stopwords and word not in punctuations):
      stem_word=stemmer.stem(word)
      cleaned_tokens.append(stem_word)
  return cleaned_tokens

# %%
#eg of process
process(train[0])
# Out:
# ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']

# %% [markdown]
# Rename inputs and outputs

# %%
X_train=train
y_train=train_label
X_test=test
y_test=test_label

# %% [markdown]
# # Feature Extraction

# %% [markdown]
# making a dictionary, which contains {(word,label):counts,........}
#
# key   > (word,label)
#
# value > counts...how much appears

# %%
X_train[:3]        #first 3 tweets
# Out:
# ['#FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)',
#  '@Lamb2ja Hey James! How odd :/ Please call our Contact Centre on 02392441234 and we will be able to assist you :) Many thanks!',
#  '@DespiteOfficial we had a listen last night :) As You Bleed is an amazing track. When are you in Scotland?!']

# %%
y_train
# Out:
# array([1., 1., 1., ..., 0., 0., 0.])

# %%
result={}
for y,tweet in zip(y_train,X_train):
  for word in process(tweet):
    pair=(word,y)
    if pair in result:
      result[pair] += 1
    else:
      result[pair] = 1

result
# Out:
# {('followfriday', 1.0): 23,
#  ('top', 1.0): 30,
#  ('engag', 1.0): 7,
#  ('member', 1.0): 14,
#  ('commun', 1.0): 27,
#  ('week', 1.0): 72,
#  (':)', 1.0): 2847,
#  ('hey', 1.0): 60,
#  ('jame', 1.0): 7,
#  ('odd', 1.0): 2,
#  (':/', 1.0): 5,
#  ('pleas', 1.0): 80,
#  ('call', 1.0): 27,
#  ('contact', 1.0): 4,
#  ('centr', 1.0): 1,
#  ('02392441234', 1.0): 1,
#  ('abl', 1.0): 6,
#  ('assist', 1.0): 1,
#  ('mani', 1.0): 28,
#  ('thank', 1.0): 504,
#  ('listen', 1.0): 14,
#  ('last', 1.0): 39,
#  ('night', 1.0): 55,
#  ('bleed', 1.0): 2,
#  ('amaz', 1.0): 41,
#  ('track', 1.0): 5,
#  ('scotland', 1.0): 2,
#  ('congrat', 1.0): 15,
#  ('yeaaah', 1.0): 1,
#  ('yipppi', 1.0): 1,
#  ('accnt', 1.0): 2,
#  ('verifi', 1.0): 2,
#  ('rqst', 1.0): 1,
#  ('succeed', 1.0): 1,
#  ('got', 1.0): 57,
#  ('blue', 1.0): 8,
#  ('tick', 1.0): 1,
#  ('mark', 1.0): 1,
#  ('fb', 1.0): 4,
#  ('profil', 1.0): 2,
#  ('15', 1.0): 4,
#  ('day', 1.0): 187,
#  ('one', 1.0): 90,
#  ('irresist', 1.0): 2,
#  ('flipkartfashionfriday', 1.0): 16,
#  ('like', 1.0): 187,
#  ('keep', 1.0): 55,
#  ('love', 1.0): 336,
#  ('custom', 1.0): 4,
#  ('wait', 1.0): 55,
#  ('long', 1.0): 27,
#  ('hope', 1.0): 113,
#  ('enjoy', 1.0): 57,
#  ('happi', 1.0): 161,
#  ('friday', 1.0): 91,
#  ('lwwf', 1.0): 1,
#  ('second', 1.0): 8,
#  ('thought', 1.0): 21,
#  ('’', 1.0): 17,
#  ('enough', 1.0): 16,
#  ('time', 1.0): 100,
#  ('dd', 1.0): 1,
#  ('new', 1.0): 111,
#  ('short', 1.0): 6,
#  ('enter', 1.0): 9,
#  ('system', 1.0): 2,
#  ('sheep', 1.0): 1,
#  ('must', 1.0): 14,
#  ('buy', 1.0): 9,
#  ('jgh', 1.0): 4,
#  ('go', 1.0): 120,
#  ('bayan', 1.0): 1,
#  (':D', 1.0): 498,
#  ('bye', 1.0): 5,
#  ('act', 1.0): 6,
#  ('mischiev', 1.0): 1,
#  ('etl', 1.0): 1,
#  ('layer', 1.0): 1,
#  ('in-hous', 1.0): 1,
#  ('wareh', 1.0): 1,
#  ('app', 1.0): 12,
#  ('katamari', 1.0): 1,
#  ('well', 1.0): 66,
#  ('…', 1.0): 31,
#  ('name', 1.0): 12,
#  ('impli', 1.0): 1,
#  (':p', 1.0): 103,
#  ('influenc', 1.0): 16,
#  ('big', 1.0): 27,
#  ('...', 1.0): 227,
#  ('juici', 1.0): 3,
#  ('selfi', 1.0): 11,
#  ('follow', 1.0): 319,
#  ('perfect', 1.0): 17,
#  ('alreadi', 1.0): 19,
#  ('know', 1.0): 120,
#  ("what'", 1.0): 14,
#  ('great', 1.0): 134,
#  ('opportun', 1.0): 17,
#  ('junior', 1.0): 2,
#  ('triathlet', 1.0): 1,
#  ('age', 1.0): 2,
#  ('12', 1.0): 5,
#  ('13', 1.0): 5,
#  ('gatorad', 1.0): 1,
#  ('seri', 1.0): 4,
#  ('get', 1.0): 164,
#  ('entri', 1.0): 3,
#  ('lay', 1.0): 3,
#  ('greet', 1.0): 4,
#  ('card', 1.0): 6,
#  ('rang', 1.0): 2,
#  ('print', 1.0): 3,
#  ('today', 1.0): 86,
#  ('job', 1.0): 34,
#  (':-)', 1.0): 543,
#  ("friend'", 1.0): 3,
#  ('lunch', 1.0): 3,
#  ('yummm', 1.0): 1,
#  ('nostalgia', 1.0): 1,
#  ('tb', 1.0): 1,
#  ('ku', 1.0): 1,
#  ('id', 1.0): 8,
#  ('conflict', 1.0): 1,
#  ('help', 1.0): 37,
#  ("here'", 1.0): 20,
#  ('screenshot', 1.0): 2,
#  ('work', 1.0): 88,
#  ('hi', 1.0): 154,
#  ('liv', 1.0): 2,
#  ('hello', 1.0): 49,
#  ('need', 1.0): 62,
#  ('someth', 1.0): 25,
#  ('u', 1.0): 136,
#  ('fm', 1.0): 2,
#  ('twitter', 1.0): 25,
#  ('—', 1.0): 22,
#  ('sure', 1.0): 37,
#  ('thing', 1.0): 48,
#  ('dm', 1.0): 34,
#  ('x', 1.0): 50,
#  ("i'v", 1.0): 25,
#  ('heard', 1.0): 9,
#  ('four', 1.0): 5,
#  ('season', 1.0): 5,
#  ('pretti', 1.0): 17,
#  ('dope', 1.0): 2,
#  ('penthous', 1.0): 1,
#  ('obv', 1.0): 1,
#  ('gobigorgohom', 1.0): 1,
#  ('fun', 1.0): 45,
#  ("y'all", 1.0): 3,
#  ('yeah', 1.0): 30,
#  ('suppos', 1.0): 6,
#  ('lol', 1.0): 48,
#  ('chat', 1.0): 9,
#  ('bit', 1.0): 16,
#  ('youth', 1.0): 14,
#  ('💅', 1.0): 1,
#  ('🏽', 1.0): 1,
#  ('💋', 1.0): 2,
#  ('seen', 1.0): 6,
#  ('year', 1.0): 33,
#  ('rest', 1.0): 9,
#  ('goe', 1.0): 4,
#  ('quickli', 1.0): 3,
#  ('bed', 1.0): 8,
#  ('music', 1.0): 15,
#  ('fix', 1.0): 6,
#  ('dream', 1.0): 17,
#  ('spiritu', 1.0): 1,
#  ('ritual', 1.0): 1,
#  ('festiv', 1.0): 7,
#  ('népal', 1.0): 1,
#  ('begin', 1.0): 4,
#  ('line-up', 1.0): 4,
#  ('left', 1.0): 10,
#  ('see', 1.0): 156,
#  ('sarah', 1.0): 4,
#  ('send', 1.0): 17,
#  ('us', 1.0): 91,
#  ('email', 1.0): 22,
#  ('bitsy@bitdefender.com', 1.0): 1,
#  ("we'll", 1.0): 12,
#  ('asap', 1.0): 5,
#  ('kik', 1.0): 16,
#  ('hatessuc', 1.0): 1,
#  ('32429', 1.0): 1,
#  ('kikm', 1.0): 1,
#  ('lgbt', 1.0): 2,
#  ('tinder', 1.0): 1,
#  ('nsfw', 1.0): 1,
#  ('akua', 1.0): 1,
#  ('cumshot', 1.0): 1,
#  ('come', 1.0): 63,
#  ('hous', 1.0): 5,
#  ('nsn_supplement', 1.0): 1,
#  ('effect', 1.0): 2,
#  ('press', 1.0): 1,
#  ('releas', 1.0): 11,
#  ('distribut', 1.0): 1,
#  ('result', 1.0): 2,
#  ('link', 1.0): 13,
#  ('remov', 1.0): 3,
#  ('pressreleas', 1.0): 1,
#  ('newsdistribut', 1.0): 1,
#  ('bam', 1.0): 44,
#  ('bestfriend', 1.0): 50,
#  ('lot', 1.0): 80,
#  ('warsaw', 1.0): 44,
#  ('<3', 1.0): 118,
#  ('x46', 1.0): 1,
#  ('everyon', 1.0): 45,
#  ('watch', 1.0): 32,
#  ('documentari', 1.0): 1,
#  ('earthl', 1.0): 1,
#  ('youtub', 1.0): 8,
#  ('support', 1.0): 25,
#  ('buuut', 1.0): 1,
#  ('oh', 1.0): 44,
#  ('look', 1.0): 109,
#  ('forward', 1.0): 20,
#  ('visit', 1.0): 25,
#  ('next', 1.0): 37,
#  ('letsgetmessi', 1.0): 1,
#  ('jo', 1.0): 1,
#  ('make', 1.0): 69,
#  ('feel', 1.0): 33,
#  ('better', 1.0): 40,
#  ('never', 1.0): 31,
#  ('anyon', 1.0): 7,
#  ('kpop', 1.0): 1,
#  ('flesh', 1.0): 1,
#  ('good', 1.0): 191,
#  ('girl', 1.0): 34,
#  ('best', 1.0): 49,
#  ('wish', 1.0): 29,
#  ('reason', 1.0): 10,
#  ('epic', 1.0): 1,
#  ('soundtrack', 1.0): 1,
#  ('shout', 1.0): 11,
#  ('ad', 1.0): 10,
#  ('video', 1.0): 29,
#  ('playlist', 1.0): 5,
#  ('would', 1.0): 70,
#  ('dear', 1.0): 15,
#  ('jordan', 1.0): 1,
#  ('okay', 1.0): 31,
#  ('fake', 1.0): 1,
#  ('gameplay', 1.0): 1,
#  (';)', 1.0): 22,
#  ('haha', 1.0): 44,
#  ('im', 1.0): 38,
#  ('kid', 1.0): 13,
#  ('stuff', 1.0): 11,
#  ('exactli', 1.0): 5,
#  ('product', 1.0): 11,
#  ('line', 1.0): 6,
#  ('etsi', 1.0): 1,
#  ('shop', 1.0): 12,
#  ('check', 1.0): 38,
#  ('vacat', 1.0): 5,
#  ('recharg', 1.0): 1,
#  ('normal', 1.0): 5,
#  ('charger', 1.0): 2,
#  ('asleep', 1.0): 7,
#  ('talk', 1.0): 37,
#  ('sooo', 1.0): 6,
#  ('someon', 1.0): 29,
#  ('text', 1.0): 12,
#  ('ye', 1.0): 60,
#  ('bet', 1.0): 6,
#  ("he'll", 1.0): 2,
#  ('fit', 1.0): 2,
#  ('hear', 1.0): 24,
#  ('speech', 1.0): 1,
#  ('piti', 1.0): 2,
#  ('green', 1.0): 2,
#  ('garden', 1.0): 5,
#  ('midnight', 1.0): 1,
#  ('sun', 1.0): 6,
#  ('beauti', 1.0): 45,
#  ('canal', 1.0): 1,
#  ('dasvidaniya', 1.0): 1,
#  ('till', 1.0): 16,
#  ('scout', 1.0): 1,
#  ('sg', 1.0): 1,
#  ('futur', 1.0): 9,
#  ('wlan', 1.0): 1,
#  ('pro', 1.0): 4,
#  ('confer', 1.0): 1,
#  ('asia', 1.0): 1,
#  ('chang', 1.0): 20,
#  ('lollipop', 1.0): 1,
#  ('🍭', 1.0): 1,
#  ('nez', 1.0): 1,
#  ('agnezmo', 1.0): 1,
#  ('oley', 1.0): 1,
#  ('mama', 1.0): 1,
#  ('stand', 1.0): 6,
#  ('stronger', 1.0): 1,
#  ('god', 1.0): 14,
#  ('misti', 1.0): 1,
#  ('babi', 1.0): 17,
#  ('cute', 1.0): 21,
#  ('woohoo', 1.0): 3,
#  ("can't", 1.0): 31,
#  ('sign', 1.0): 9,
#  ('yet', 1.0): 12,
#  ('still', 1.0): 37,
#  ('think', 1.0): 48,
#  ('mka', 1.0): 5,
#  ('liam', 1.0): 5,
#  ('access', 1.0): 3,
#  ('welcom', 1.0): 54,
#  ('stat', 1.0): 51,
#  ('arriv', 1.0): 57,
#  ('1', 1.0): 60,
#  ('unfollow', 1.0): 53,
#  ('via', 1.0): 60,
#  ('surpris', 1.0): 10,
#  ('figur', 1.0): 5,
#  ('happybirthdayemilybett', 1.0): 1,
#  ('sweet', 1.0): 16,
#  ('talent', 1.0): 4,
#  ('2', 1.0): 41,
#  ('plan', 1.0): 21,
#  ('drain', 1.0): 1,
#  ('gotta', 1.0): 4,
#  ('timezon', 1.0): 1,
#  ('parent', 1.0): 4,
#  ('proud', 1.0): 11,
#  ('least', 1.0): 14,
#  ('mayb', 1.0): 17,
#  ('sometim', 1.0): 11,
#  ('grade', 1.0): 4,
#  ('al', 1.0): 3,
#  ('grand', 1.0): 4,
#  ('manila_bro', 1.0): 1,
#  ('chosen', 1.0): 1,
#  ('let', 1.0): 57,
#  ('around', 1.0): 14,
#  ('..', 1.0): 100,
#  ('side', 1.0): 13,
#  ('world', 1.0): 23,
#  ('eh', 1.0): 2,
#  ('take', 1.0): 30,
#  ('care', 1.0): 12,
#  ('final', 1.0): 24,
#  ('fuck', 1.0): 20,
#  ('weekend', 1.0): 61,
#  ('real', 1.0): 18,
#  ('x45', 1.0): 1,
#  ('join', 1.0): 21,
#  ('hushedcallwithfraydo', 1.0): 1,
#  ('gift', 1.0): 7,
#  ('yeahhh', 1.0): 1,
#  ('hushedpinwithsammi', 1.0): 2,
#  ('event', 1.0): 7,
#  ('might', 1.0): 21,
#  ('luv', 1.0): 4,
#  ('realli', 1.0): 66,
#  ('appreci', 1.0): 28,
#  ('share', 1.0): 41,
#  ('wow', 1.0): 14,
#  ('tom', 1.0): 5,
#  ('gym', 1.0): 3,
#  ('monday', 1.0): 7,
#  ('invit', 1.0): 15,
#  ('scope', 1.0): 5,
#  ('friend', 1.0): 40,
#  ('nude', 1.0): 1,
#  ('sleep', 1.0): 35,
#  ('birthday', 1.0): 53,
#  ('want', 1.0): 69,
#  ('t-shirt', 1.0): 2,
#  ('cool', 1.0): 29,
#  ('haw', 1.0): 1,
#  ('phela', 1.0): 1,
#  ('mom', 1.0): 7,
#  ('obvious', 1.0): 1,
#  ('princ', 1.0): 1,
#  ('charm', 1.0): 1,
#  ('stage', 1.0): 2,
#  ('luck', 1.0): 26,
#  ('tyler', 1.0): 1,
#  ('hipster', 1.0): 1,
#  ('glass', 1.0): 3,
#  ('marti', 1.0): 2,
#  ('glad', 1.0): 41,
#  ('done', 1.0): 40,
#  ('afternoon', 1.0): 7,
#  ('read', 1.0): 27,
#  ('kahfi', 1.0): 1,
#  ('finish', 1.0): 15,
#  ('ohmyg', 1.0): 1,
#  ('yaya', 1.0): 3,
#  ('dub', 1.0): 1,
#  ('stalk', 1.0): 2,
#  ('ig', 1.0): 3,
#  ('gondooo', 1.0): 1,
#  ('moo', 1.0): 2,
#  ('tologooo', 1.0): 1,
#  ('becom', 1.0): 8,
#  ('detail', 1.0): 8,
#  ('zzz', 1.0): 1,
#  ('xx', 1.0): 33,
#  ('physiotherapi', 1.0): 1,
#  ('hashtag', 1.0): 3,
#  ('💪', 1.0): 1,
#  ('monica', 1.0): 1,
#  ('miss', 1.0): 17,
#  ('sound', 1.0): 20,
#  ('morn', 1.0): 68,
#  ("that'", 1.0): 49,
#  ('x43', 1.0): 1,
#  ('definit', 1.0): 20,
#  ('tri', 1.0): 34,
#  ('tonight', 1.0): 15,
#  ('took', 1.0): 7,
#  ('advic', 1.0): 6,
#  ('treviso', 1.0): 1,
#  ('concert', 1.0): 23,
#  ('citi', 1.0): 26,
#  ('countri', 1.0): 22,
#  ("i'll", 1.0): 73,
#  ('start', 1.0): 56,
#  ('fine', 1.0): 7,
#  ('gorgeou', 1.0): 9,
#  ('xo', 1.0): 2,
#  ('oven', 1.0): 2,
#  ('roast', 1.0): 1,
#  ('garlic', 1.0): 1,
#  ('oliv', 1.0): 1,
#  ('oil', 1.0): 4,
#  ('dri', 1.0): 4,
#  ('tomato', 1.0): 1,
#  ('basil', 1.0): 1,
#  ('centuri', 1.0): 1,
#  ('tuna', 1.0): 1,
#  ('right', 1.0): 38,
#  ('back', 1.0): 74,
#  ('atchya', 1.0): 1,
#  ('even', 1.0): 26,
#  ('almost', 1.0): 8,
#  ('chanc', 1.0): 3,
#  ('cheer', 1.0): 17,
#  ('po', 1.0): 3,
#  ('ice', 1.0): 6,
#  ('cream', 1.0): 6,
#  ('agre', 1.0): 13,
#  ('100', 1.0): 6,
#  ('heheheh', 1.0): 2,
#  ('that', 1.0): 10,
#  ('point', 1.0): 11,
#  ('stay', 1.0): 20,
#  ('home', 1.0): 20,
#  ('soon', 1.0): 38,
#  ('promis', 1.0): 4,
#  ('web', 1.0): 4,
#  ('whatsapp', 1.0): 3,
#  ('volta', 1.0): 1,
#  ('funcionar', 1.0): 1,
#  ('com', 1.0): 2,
#  ('iphon', 1.0): 7,
#  ('jailbroken', 1.0): 1,
#  ('later', 1.0): 11,
#  ('34', 1.0): 3,
#  ('min', 1.0): 7,
#  ('leia', 1.0): 1,
#  ('appear', 1.0): 3,
#  ('hologram', 1.0): 1,
#  ('r2d2', 1.0): 1,
#  ('w', 1.0): 16,
#  ('messag', 1.0): 9,
#  ('obi', 1.0): 1,
#  ('wan', 1.0): 1,
#  ('sit', 1.0): 7,
#  ('luke', 1.0): 4,
#  ('inter', 1.0): 1,
#  ('3', 1.0): 26,
#  ('ucl', 1.0): 1,
#  ('arsen', 1.0): 2,
#  ('small', 1.0): 1,
#  ('team', 1.0): 24,
#  ('pass', 1.0): 10,
#  ('🚂', 1.0): 1,
#  ('dewsburi', 1.0): 2,
#  ('railway', 1.0): 1,
#  ('station', 1.0): 4,
#  ('dew', 1.0): 1,
#  ('west', 1.0): 1,
#  ('yorkshir', 1.0): 2,
#  ('430', 1.0): 1,
#  ('smh', 1.0): 2,
#  ('9:25', 1.0): 1,
#  ('live', 1.0): 21,
#  ('strang', 1.0): 4,
#  ('imagin', 1.0): 5,
#  ('megan', 1.0): 1,
#  ('masaantoday', 1.0): 4,
#  ('a4', 1.0): 3,
#  ('shweta', 1.0): 1,
#  ('tripathi', 1.0): 1,
#  ('5', 1.0): 15,
#  ('20', 1.0): 5,
#  ('kurta', 1.0): 3,
#  ('half', 1.0): 6,
#  ('number', 1.0): 11,
#  ('wsalelov', 1.0): 14,
#  ('ah', 1.0): 12,
#  ('larri', 1.0): 3,
#  ('anyway', 1.0): 14,
#  ('kinda', 1.0): 12,
#  ('goood', 1.0): 1,
#  ('life', 1.0): 36,
#  ('enn', 1.0): 1,
#  ('could', 1.0): 25,
#  ('warmup', 1.0): 1,
#  ('15th', 1.0): 2,
#  ('bath', 1.0): 6,
#  ('dum', 1.0): 2,
#  ('andar', 1.0): 1,
#  ('ram', 1.0): 1,
#  ('sampath', 1.0): 1,
#  ('sona', 1.0): 1,
#  ('mohapatra', 1.0): 1,
#  ('samantha', 1.0): 1,
#  ('edward', 1.0): 1,
#  ('mein', 1.0): 1,
#  ('tulan', 1.0): 1,
#  ('razi', 1.0): 2,
#  ('wah', 1.0): 2,
#  ('josh', 1.0): 1,
#  ('alway', 1.0): 48,
#  ('smile', 1.0): 47,
#  ('pictur', 1.0): 7,
#  ('16.20', 1.0): 1,
#  ('giveitup', 1.0): 1,
#  ('given', 1.0): 3,
#  ('ga', 1.0): 3,
#  ('subsidi', 1.0): 1,
#  ('initi', 1.0): 2,
#  ('propos', 1.0): 3,
#  ('delight', 1.0): 4,
#  ('yesterday', 1.0): 4,
#  ('x42', 1.0): 1,
#  ('lmaoo', 1.0): 2,
#  ('song', 1.0): 16,
#  ('ever', 1.0): 19,
#  ('shall', 1.0): 5,
#  ('littl', 1.0): 29,
#  ('throwback', 1.0): 3,
#  ('outli', 1.0): 1,
#  ('island', 1.0): 2,
#  ('cheung', 1.0): 1,
#  ('chau', 1.0): 1,
#  ('mui', 1.0): 1,
#  ('wo', 1.0): 1,
#  ('total', 1.0): 5,
#  ('differ', 1.0): 10,
#  ('kfckitchentour', 1.0): 2,
#  ('kitchen', 1.0): 3,
#  ('clean', 1.0): 1,
#  ("i'm", 1.0): 140,
#  ('cusp', 1.0): 1,
#  ('test', 1.0): 7,
#  ('water', 1.0): 7,
#  ('reward', 1.0): 1,
#  ('arummzz', 1.0): 2,
#  ("let'", 1.0): 18,
#  ('drive', 1.0): 9,
#  ('travel', 1.0): 19,
#  ('yogyakarta', 1.0): 3,
#  ('jeep', 1.0): 3,
#  ('indonesia', 1.0): 3,
#  ('instamood', 1.0): 3,
#  ('wanna', 1.0): 23,
#  ('skype', 1.0): 3,
#  ('may', 1.0): 16,
#  ('nice', 1.0): 70,
#  ('friendli', 1.0): 1,
#  ('pretend', 1.0): 2,
#  ('film', 1.0): 8,
#  ('congratul', 1.0): 9,
#  ('winner', 1.0): 3,
#  ('cheesydelight', 1.0): 1,
#  ('contest', 1.0): 5,
#  ('address', 1.0): 8,
#  ('guy', 1.0): 48,
#  ('market', 1.0): 5,
#  ('24/7', 1.0): 1,
#  ('14', 1.0): 1,
#  ('hour', 1.0): 24,
#  ('leav', 1.0): 11,
#  ('without', 1.0): 9,
#  ('delay', 1.0): 1,
#  ('actual', 1.0): 13,
#  ('easi', 1.0): 7,
#  ('guess', 1.0): 8,
#  ('train', 1.0): 7,
#  ('wd', 1.0): 1,
#  ('shift', 1.0): 4,
#  ('engin', 1.0): 1,
#  ('etc', 1.0): 2,
#  ('sunburn', 1.0): 1,
#  ('peel', 1.0): 2,
#  ('blog', 1.0): 27,
#  ('huge', 1.0): 9,
#  ('warm', 1.0): 4,
#  ('☆', 1.0): 3,
#  ('complet', 1.0): 10,
#  ('triangl', 1.0): 2,
#  ('northern', 1.0): 1,
#  ('ireland', 1.0): 2,
#  ('sight', 1.0): 1,
#  ('smthng', 1.0): 2,
#  ('fr', 1.0): 3,
#  ('hug', 1.0): 11,
#  ('xoxo', 1.0): 3,
#  ('uu', 1.0): 1,
#  ('jaann', 1.0): 1,
#  ('topnewfollow', 1.0): 2,
#  ('connect', 1.0): 13,
#  ('wonder', 1.0): 26,
#  ('made', 1.0): 38,
#  ('fluffi', 1.0): 1,
#  ('insid', 1.0): 7,
#  ('pirouett', 1.0): 1,
#  ('moos', 1.0): 1,
#  ('trip', 1.0): 12,
#  ('philli', 1.0): 1,
#  ('decemb', 1.0): 2,
#  ("i'd", 1.0): 13,
#  ('dude', 1.0): 6,
#  ('x41', 1.0): 1,
#  ('question', 1.0): 15,
#  ('flaw', 1.0): 1,
#  ('pain', 1.0): 8,
#  ('negat', 1.0): 1,
#  ('strength', 1.0): 2,
#  ('went', 1.0): 10,
#  ('solo', 1.0): 4,
#  ('move', 1.0): 9,
#  ('fav', 1.0): 11,
#  ('nirvana', 1.0): 1,
#  ('smell', 1.0): 2,
#  ('teen', 1.0): 3,
#  ('spirit', 1.0): 1,
#  ('rip', 1.0): 3,
#  ('ami', 1.0): 4,
#  ('winehous', 1.0): 1,
#  ('coupl', 1.0): 5,
#  ('tomhiddleston', 1.0): 1,
#  ('elizabetholsen', 1.0): 1,
#  ('yaytheylookgreat', 1.0): 1,
#  ('goodnight', 1.0): 18,
#  ('vid', 1.0): 8,
#  ('wake', 1.0): 10,
#  ('gonna', 1.0): 16,
#  ('shoot', 1.0): 5,
#  ('itti', 1.0): 2,
#  ('bitti', 1.0): 2,
#  ('teeni', 1.0): 2,
#  ('bikini', 1.0): 3,
#  ('much', 1.0): 73,
#  ('4th', 1.0): 4,
#  ('togeth', 1.0): 6,
#  ('end', 1.0): 13,
#  ('xfile', 1.0): 1,
#  ('content', 1.0): 3,
#  ('rain', 1.0): 18,
#  ('fabul', 1.0): 4,
#  ('fantast', 1.0): 8,
#  ('♡', 1.0): 12,
#  ('jb', 1.0): 1,
#  ('forev', 1.0): 5,
#  ('belieb', 1.0): 3,
#  ('nighti', 1.0): 1,
#  ('bug', 1.0): 2,
#  ('bite', 1.0): 1,
#  ('bracelet', 1.0): 2,
#  ('idea', 1.0): 23,
#  ('foundri', 1.0): 1,
#  ('game', 1.0): 23,
#  ('sens', 1.0): 6,
#  ('pic', 1.0): 21,
#  ('ef', 1.0): 1,
#  ('phone', 1.0): 16,
#  ('woot', 1.0): 2,
#  ('derek', 1.0): 1,
#  ('use', 1.0): 32,
#  ('parkshar', 1.0): 1,
#  ('gloucestershir', 1.0): 1,
#  ('aaaahhh', 1.0): 1,
#  ('man', 1.0): 16,
#  ('traffic', 1.0): 2,
#  ('stress', 1.0): 4,
#  ('reliev', 1.0): 1,
#  ("how'r", 1.0): 1,
#  ('arbeloa', 1.0): 1,
#  ('turn', 1.0): 13,
#  ('17', 1.0): 2,
#  ('omg', 1.0): 13,
#  ('say', 1.0): 43,
#  ('europ', 1.0): 1,
#  ('rise', 1.0): 2,
#  ('find', 1.0): 20,
#  ('hard', 1.0): 9,
#  ('believ', 1.0): 7,
#  ('uncount', 1.0): 1,
#  ('coz', 1.0): 2,
#  ('unlimit', 1.0): 1,
#  ('cours', 1.0): 11,
#  ('teamposit', 1.0): 1,
#  ('aldub', 1.0): 2,
#  ('☕', 1.0): 3,
#  ('rita', 1.0): 2,
#  ('info', 1.0): 10,
#  ("we'd", 1.0): 4,
#  ('way', 1.0): 34,
#  ('boy', 1.0): 13,
#  ('x40', 1.0): 1,
#  ('true', 1.0): 19,
#  ('sethi', 1.0): 2,
#  ('high', 1.0): 6,
#  ('exe', 1.0): 1,
#  ('skeem', 1.0): 1,
#  ('saam', 1.0): 1,
#  ('peopl', 1.0): 42,
#  ('polit', 1.0): 2,
#  ('izzat', 1.0): 1,
#  ('wese', 1.0): 1,
#  ('trust', 1.0): 7,
#  ('khawateen', 1.0): 1,
#  ('k', 1.0): 8,
#  ('sath', 1.0): 2,
#  ('mana', 1.0): 1,
#  ('kar', 1.0): 1,
#  ('deya', 1.0): 1,
#  ('sort', 1.0): 7,
#  ('smart', 1.0): 5,
#  ('hair', 1.0): 7,
#  ('tbh', 1.0): 5,
#  ('jacob', 1.0): 2,
#  ('g', 1.0): 7,
#  ('upgrad', 1.0): 2,
#  ('tee', 1.0): 2,
#  ('famili', 1.0): 14,
#  ('person', 1.0): 14,
#  ('two', 1.0): 15,
#  ('convers', 1.0): 6,
#  ('onlin', 1.0): 4,
#  ('mclaren', 1.0): 1,
#  ('fridayfeel', 1.0): 5,
#  ('tgif', 1.0): 8,
#  ('squar', 1.0): 1,
#  ('enix', 1.0): 1,
#  ('bissmillah', 1.0): 1,
#  ('ya', 1.0): 19,
#  ('allah', 1.0): 3,
#  ("we'r", 1.0): 25,
#  ('socent', 1.0): 1,
#  ('startup', 1.0): 2,
#  ('drop', 1.0): 9,
#  ('your', 1.0): 3,
#  ('arnd', 1.0): 1,
#  ('town', 1.0): 3,
#  ('basic', 1.0): 4,
#  ('piss', 1.0): 2,
#  ('cup', 1.0): 4,
#  ('also', 1.0): 28,
#  ('terribl', 1.0): 2,
#  ('complic', 1.0): 1,
#  ('discuss', 1.0): 2,
#  ('snapchat', 1.0): 31,
#  ('lynettelow', 1.0): 1,
#  ('kikmenow', 1.0): 2,
#  ('snapm', 1.0): 1,
#  ('hot', 1.0): 20,
#  ('amazon', 1.0): 1,
#  ('kikmeguy', 1.0): 2,
#  ('defin', 1.0): 2,
#  ('grow', 1.0): 6,
#  ('sport', 1.0): 4,
#  ('rt', 1.0): 9,
#  ('rakyat', 1.0): 1,
#  ('write', 1.0): 11,
#  ('sinc', 1.0): 11,
#  ('mention', 1.0): 18,
#  ('fli', 1.0): 5,
#  ('fish', 1.0): 3,
#  ('promot', 1.0): 3,
#  ('post', 1.0): 16,
#  ('cyber', 1.0): 1,
#  ('ourdaughtersourprid', 1.0): 3,
#  ('mypapamyprid', 1.0): 2,
#  ('papa', 1.0): 1,
#  ('coach', 1.0): 2,
#  ('posit', 1.0): 3,
#  ('kha', 1.0): 1,
#  ('atleast', 1.0): 2,
#  ('x39', 1.0): 1,
#  ('mango', 1.0): 1,
#  ("lassi'", 1.0): 1,
#  ("monty'", 1.0): 1,
#  ('marvel', 1.0): 2,
#  ('though', 1.0): 16,
#  ('suspect', 1.0): 3,
#  ('meant', 1.0): 2,
#  ('24', 1.0): 3,
#  ('hr', 1.0): 2,
#  ('touch', 1.0): 7,
#  ('kepler', 1.0): 3,
#  ('452b', 1.0): 4,
#  ('chalna', 1.0): 1,
#  ('hai', 1.0): 7,
#  ('thankyou', 1.0): 12,
#  ('hazel', 1.0): 1,
#  ('food', 1.0): 6,
#  ('brooklyn', 1.0): 1,
#  ('pta', 1.0): 2,
#  ('awak', 1.0): 8,
#  ('okayi', 1.0): 2,
#  ('awww', 1.0): 12,
#  ('ha', 1.0): 18,
#  ('doc', 1.0): 1,
#  ('splendid', 1.0): 1,
#  ('spam', 1.0): 1,
#  ('folder', 1.0): 1,
#  ('amount', 1.0): 1,
#  ('nigeria', 1.0): 1,
#  ('claim', 1.0): 1,
#  ('rted', 1.0): 1,
#  ('leg', 1.0): 3,
#  ('hurt', 1.0): 4,
#  ('bad', 1.0): 14,
#  ('mine', 1.0): 11,
#  ('saturday', 1.0): 5,
#  ('thaaank', 1.0): 1,
#  ('puhon', 1.0): 1,
#  ('happinesss', 1.0): 1,
#  ('tnc', 1.0): 1,
#  ('prior', 1.0): 1,
#  ('notif', 1.0): 2,
#  ('fat', 1.0): 1,
#  ('co', 1.0): 1,
#  ('probabl', 1.0): 7,
#  ('ate', 1.0): 4,
#  ('yuna', 1.0): 2,
#  ('tamesid', 1.0): 1,
#  ('´', 1.0): 3,
#  ('googl', 1.0): 5,
#  ('account', 1.0): 17,
#  ('scouser', 1.0): 1,
#  ('everyth', 1.0): 10,
#  ('zoe', 1.0): 1,
#  ('mate', 1.0): 5,
#  ('liter', 1.0): 5,
#  ("they'r", 1.0): 10,
#  ('samee', 1.0): 1,
#  ('edgar', 1.0): 1,
#  ('updat', 1.0): 12,
#  ('log', 1.0): 3,
#  ('bring', 1.0): 12,
#  ('abe', 1.0): 1,
#  ('meet', 1.0): 26,
#  ('x38', 1.0): 1,
#  ('sigh', 1.0): 3,
#  ('dreamili', 1.0): 1,
#  ('pout', 1.0): 1,
#  ('eye', 1.0): 12,
#  ('quacketyquack', 1.0): 6,
#  ('funni', 1.0): 15,
#  ('happen', 1.0): 13,
#  ('phil', 1.0): 1,
#  ('em', 1.0): 2,
#  ('del', 1.0): 1,
#  ('rodder', 1.0): 1,
#  ('els', 1.0): 8,
#  ('play', 1.0): 37,
#  ('newest', 1.0): 1,
#  ('gamejam', 1.0): 1,
#  ('irish', 1.0): 2,
#  ('literatur', 1.0): 2,
#  ('inaccess', 1.0): 2,
#  ("kareena'", 1.0): 2,
#  ('fan', 1.0): 21,
#  ('brain', 1.0): 10,
#  ('dot', 1.0): 8,
#  ('braindot', 1.0): 8,
#  ('fair', 1.0): 4,
#  ('rush', 1.0): 1,
#  ('either', 1.0): 10,
#  ('brandi', 1.0): 1,
#  ('18', 1.0): 5,
#  ('carniv', 1.0): 1,
#  ('men', 1.0): 8,
#  ('put', 1.0): 11,
#  ('mask', 1.0): 2,
#  ('xavier', 1.0): 1,
#  ('forneret', 1.0): 1,
#  ('jennif', 1.0): 1,
#  ('site', 1.0): 7,
#  ('free', 1.0): 31,
#  ('50.000', 1.0): 3,
#  ('8', 1.0): 10,
#  ('ball', 1.0): 7,
#  ('pool', 1.0): 5,
#  ('coin', 1.0): 5,
#  ('edit', 1.0): 6,
#  ('trish', 1.0): 1,
#  ('♥', 1.0): 13,
#  ('grate', 1.0): 5,
#  ('three', 1.0): 8,
#  ('comment', 1.0): 7,
#  ('wakeup', 1.0): 1,
#  ('besid', 1.0): 2,
#  ('dirti', 1.0): 2,
#  ('sex', 1.0): 4,
#  ('lmaooo', 1.0): 1,
#  ('😤', 1.0): 2,
#  ('loui', 1.0): 4,
#  ("he'", 1.0): 10,
#  ('throw', 1.0): 3,
#  ('caus', 1.0): 11,
#  ('inspir', 1.0): 6,
#  ('ff', 1.0): 40,
#  ('twoof', 1.0): 3,
#  ('gr8', 1.0): 1,
#  ('wkend', 1.0): 3,
#  ('kind', 1.0): 22,
#  ('exhaust', 1.0): 2,
#  ('word', 1.0): 17,
#  ('cheltenham', 1.0): 1,
#  ('area', 1.0): 4,
#  ('kale', 1.0): 1,
#  ('crisp', 1.0): 1,
#  ('ruin', 1.0): 5,
#  ('x37', 1.0): 1,
#  ('open', 1.0): 12,
#  ('worldwid', 1.0): 2,
#  ('outta', 1.0): 1,
#  ('sfvbeta', 1.0): 1,
#  ('vantast', 1.0): 1,
#  ('xcylin', 1.0): 1,
#  ('bundl', 1.0): 1,
#  ('show', 1.0): 20,
#  ('internet', 1.0): 2,
#  ('price', 1.0): 3,
#  ('realisticli', 1.0): 1,
#  ('pay', 1.0): 8,
#  ('net', 1.0): 1,
#  ('educ', 1.0): 1,
#  ('power', 1.0): 6,
#  ('weapon', 1.0): 1,
#  ('nelson', 1.0): 1,
#  ('mandela', 1.0): 1,
#  ('recent', 1.0): 8,
#  ('j', 1.0): 2,
#  ('chenab', 1.0): 1,
#  ('flow', 1.0): 5,
#  ('pakistan', 1.0): 1,
#  ('incredibleindia', 1.0): 1,
#  ('teenchoic', 1.0): 7,
#  ('choiceinternationalartist', 1.0): 7,
#  ('superjunior', 1.0): 7,
#  ('caught', 1.0): 4,
#  ('first', 1.0): 41,
#  ('salmon', 1.0): 1,
#  ('super-blend', 1.0): 1,
#  ('project', 1.0): 6,
#  ('youth@bipolaruk.org.uk', 1.0): 1,
#  ('awesom', 1.0): 35,
#  ('stream', 1.0): 12,
#  ('alma', 1.0): 1,
#  ('mater', 1.0): 1,
#  ('highschoolday', 1.0): 1,
#  ('clientvisit', 1.0): 1,
#  ('faith', 1.0): 3,
#  ('christian', 1.0): 1,
#  ('school', 1.0): 9,
#  ('lizaminnelli', 1.0): 1,
#  ('upcom', 1.0): 2,
#  ('uk', 1.0): 4,
#  ('😄', 1.0): 3,
#  ('singl', 1.0): 4,
#  ('hill', 1.0): 4,
#  ('everi', 1.0): 23,
#  ('beat', 1.0): 7,
#  ('wrong', 1.0): 9,
#  ('readi', 1.0): 22,
#  ('natur', 1.0): 1,
#  ('pefumeri', 1.0): 1,
#  ('workshop', 1.0): 2,
#  ('neal', 1.0): 1,
#  ('yard', 1.0): 1,
#  ('covent', 1.0): 1,
#  ('tomorrow', 1.0): 31,
#  ('fback', 1.0): 26,
#  ...}

# %%
len(result)
# Out:
# 11346

# %% [markdown]
# # Training

# %% [markdown]
# Naive bayes

# %% [markdown]
# * less time to train and predict

# %% [markdown]
# 1.Identify number of classes

# %% [markdown]
# prior and logprior

# %% [markdown]
# lod(number of pos egs/number of neg egs)

# %%
#here,
#log(4000/4000)
np.log(4000/4000)
# Out:
# 0.0

# %% [markdown]
# 2.likelihood and loglikelihood

# %%
# to get logprior and loglikelihood for any word

# %% [markdown]
# find the frequencies,

# %%
def lookup(result, word, label):
    '''
    Input:
        freqs: a dictionary with the frequency of each pair (or tuple)
        word: the word to look up
        label: the label corresponding to the word
    Output:
        n: the number of times the word with its corresponding label appears.
    '''
    n = 0  # freqs.get((word, label), 0)

    pair = (word, label)
    if (pair in result):
        n = result[pair]

    return n

# %%
def NB(result,X_train,y_train):
  #to find number of unique words in the dictionary
  vocab=set([pair[0] for pair in result.keys()])
  V=len(vocab)     #length
  
  #to find logprior
  #logprior=np.log(number of total pos)-np.log(number of total neg)
  D_pos=len(list(filter(lambda x : x>0, y_train)))
  D_neg=len(list(filter(lambda x: x<=0, y_train)))
  logprior=np.log(D_pos)-np.log(D_neg)

  #to find loglikelihood
  #(freq_pos+1 / N_pos+V)
  #(freq_neg+1 / N_neg+V)
  N_pos=N_neg=0
  for pair in result.keys():
    if pair[1]>0:
      N_pos += result[pair]
    else:
      N_neg += result[pair]

  loglikelihood={}
  for word in vocab:
    freq_pos=lookup(result, word, 1)
    freq_neg=lookup(result, word, 0)

    p_pos=(freq_pos+1)/(N_pos+V)
    p_neg=(freq_neg+1)/(N_neg+V)

    loglikelihood[word] = np.log(p_pos/p_neg)

  return logprior,loglikelihood

# %%
NB(result,X_train,y_train)
# Out:
# (0.0,
#  {'ff__special': 0.6985591249960175,
#   'ms': -0.6877352361238731,
#   'lorm': -0.6877352361238731,
#   'sabadodeganarseguidor': -0.4000531636720922,
#   'ko': -0.8055182717802566,
#   '1.300': -0.6877352361238731,
#   'taco': 0.005411944436072202,
#   'manni': 0.6985591249960175,
#   'hidden': 0.6985591249960175,
#   'areadi': -0.6877352361238731,
#   'ant': -1.0932003442320375,
#   'scientist': 0.005411944436072202,
#   'mari': 0.6985591249960175,
#   'houston': 0.6985591249960175,
#   '0ne': 1.104024233104182,
#   'fineandyu': -0.6877352361238731,
#   'llaollao': -0.6877352361238731,
#   'nighti': 0.6985591249960175,
#   'etid': -0.6877352361238731,
#   'wetherspoon': -0.6877352361238731,
#   'mommi': -0.6877352361238731,
#   'straplin': -0.6877352361238731,
#   'exclud': -0.6877352361238731,
#   'assist': 0.6985591249960175,
#   'decent': 0.005411944436072202,
#   'button': 1.104024233104182,
#   'tama': -0.6877352361238731,
#   'thankyouu': -0.6877352361238731,
#   'tud': 0.6985591249960175,
#   'headphon': -0.6877352361238731,
#   'weed': 0.005411944436072202,
#   'wi̇ll': -3.578106994020038,
#   'donno': -0.6877352361238731,
#   'se': 0.41087705254423673,
#   'g': 0.005411944436072202,
#   'usual': 0.34188418105728496,
#   'spotifi': 0.6985591249960175,
#   'bi': -1.0932003442320375,
#   'tommi': -0.6877352361238731,
#   'lick': 0.005411944436072202,
#   'ghantay': -0.6877352361238731,
#   'periscop': -0.6877352361238731,
#   'dalla': -1.3808824166838185,
#   'jack': 0.29309401688785314,
#   'inact': -1.9404982046192412,
#   'yok': 0.6985591249960175,
#   'companion': -1.0932003442320375,
#   'familyhom': -0.6877352361238731,
#   'kilig': -0.6877352361238731,
#   'ai': 0.6985591249960175,
#   'whitey': 0.6985591249960175,
#   'angelica': 0.005411944436072202,
#   'chronicl': 1.3917063055559629,
#   'jummapray': 0.6985591249960175,
#   'thaaank': 0.6985591249960175,
#   'area': 0.9217026763102273,
#   'x29': 0.6985591249960175,
#   'bison': -0.6877352361238731,
#   'andam': -0.6877352361238731,
#   'fashionfriday': 0.6985591249960175,
#   'imintoh': -0.6877352361238731,
#   '..': 0.12072279094706652,
#   'imit': -0.6877352361238731,
#   'trmdhesit': 0.41087705254423673,
#   'xxx': 0.44724469671511125,
#   'balik': 0.005411944436072202,
#   'alunageorg': 0.6985591249960175,
#   'specialist': 0.6985591249960175,
#   'basil': 0.005411944436072202,
#   'sure': 0.3471612381581288,
#   'dissip': -0.6877352361238731,
#   'control': -0.4000531636720922,
#   'wolv': 1.104024233104182,
#   'trouser': -0.6877352361238731,
#   'imperi': -0.6877352361238731,
#   'sarah': 1.6148498568701726,
#   'spirit': -0.4000531636720922,
#   'evan': -0.6877352361238731,
#   'gurli': -0.6877352361238731,
#   ...})

# %%
logprior,loglikelihood=NB(result,X_train,y_train)
len(loglikelihood)
# Out:
# 9089

# %% [markdown]
# # Test score

# %% [markdown]
# if score > 0 ............positive tweet
#
# if score < 0 ............negative tweet

# %%
#score of a tweet= logprior + loglikelihood

# %%
def naive_bayes_predict(tweet, logprior,loglikelihood ):
    
    word_l = process(tweet)

    # initialize probability to zero
    p = 0

    # add the logprior
    p += logprior

    for word in word_l:

        # check if the word exists in the loglikelihood dictionary
        if word in loglikelihood:
            # add the log likelihood of that word to the probability
            p += loglikelihood[word]

    

    return p

# %%
naive_bayes_predict('i am sad', logprior,loglikelihood )
# Out:
# -2.817949103177132

# %% [markdown]
# # Test Accuracy

# %%
#def test_accuracy(X_test,y_test,logprior,loglikelihood):
y_hat=[]
for tweet in X_test:
  if naive_bayes_predict(tweet,logprior,loglikelihood) > 0:
    y_hat_i=1
  else:
    y_hat_i=0
  y_hat.append(y_hat_i)

error = np.mean(np.absolute(y_hat-y_test))
acc=1-error
acc
# Out:
# 0.994

# %% [markdown]
# 99.4 % Accuracy on test set
